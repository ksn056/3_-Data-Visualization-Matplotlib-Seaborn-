# %%
import pandas as pd

path="https://www.w3schools.com/python/pandas/dirtydata.csv"
df=pd.read_csv(path)

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
df = pd.read_csv('https://www.kaggle.com/code/davidfrank31/diabetes-detection-using-machine-learning?scriptVersionId=110243462&cellId=5')
df.head()

https://www.kaggle.com/code/davidfrank31/diabetes-detection-using-machine-learning?scriptVersionId=110243462&cellId=5
# Out:
#   File "<ipython-input-7-765d4e65ce91>", line 4
#     https://www.kaggle.com/code/davidfrank31/diabetes-detection-using-machine-learning?scriptVersionId=110243462&cellId=5
#            ^
# SyntaxError: invalid syntax

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
# Without using Matplotlib and Seaborn
import matplotlib.pyplot as plt

df.plot(kind='line')

# %%
df

# %%
df.plot(kind='hist')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Duration  32 non-null     int64
#  1   Date      31 non-null     object
#  2   Pulse     32 non-null     int64
#  3   Maxpulse  32 non-null     int64
#  4   Calories  30 non-null     float64
# dtypes: float64(1), int64(3), object(1)
# memory usage: 1.4+ KB

# %%
df["Duration"].plot(kind='line')

# %%
df["Pulse"].plot(kind='line',c='r')

# %%
df["Calories"].plot(kind='line')

# %%
df["Pulse"].plot(kind='hist')

# %%
df["Pulse"].plot(kind='hist',bins=5)

# %%
plt.hist(df["Pulse"])
# Out:
# (array([ 3.,  1.,  9., 10.,  4.,  2.,  2.,  0.,  0.,  1.]),
#  array([ 90.,  94.,  98., 102., 106., 110., 114., 118., 122., 126., 130.]),
#  <a list of 10 Patch objects>)

# %%
import matplotlib.pyplot as plt

plt.bar(df["Duration"],df["Pulse"])
# Out:
# <BarContainer object of 32 artists>

# %%
df["Pulse"].plot(kind='box')

# %%
df["Pulse"]
# Out:
# 0     110
# 1     117
# 2     103
# 3     109
# 4     117
# 5     102
# 6     110
# 7     104
# 8     109
# 9      98
# 10    103
# 11    100
# 12    100
# 13    106
# 14    104
# 15     98
# 16     98
# 17    100
# 18     90
# 19    103
# 20     97
# 21    108
# 22    100
# 23    130
# 24    105
# 25    102
# 26    100
# 27     92
# 28    103
# 29    100
# 30    102
# 31     92
# Name: Pulse, dtype: int64

# %%
df
# Out:
#     Duration          Date  Pulse  Maxpulse  Calories
# 0         60  '2020/12/01'    110       130     409.1
# 1         60  '2020/12/02'    117       145     479.0
# 2         60  '2020/12/03'    103       135     340.0
# 3         45  '2020/12/04'    109       175     282.4
# 4         45  '2020/12/05'    117       148     406.0
# 5         60  '2020/12/06'    102       127     300.0
# 6         60  '2020/12/07'    110       136     374.0
# 7        450  '2020/12/08'    104       134     253.3
# 8         30  '2020/12/09'    109       133     195.1
# 9         60  '2020/12/10'     98       124     269.0
# 10        60  '2020/12/11'    103       147     329.3
# 11        60  '2020/12/12'    100       120     250.7
# 12        60  '2020/12/12'    100       120     250.7
# 13        60  '2020/12/13'    106       128     345.3
# 14        60  '2020/12/14'    104       132     379.3
# 15        60  '2020/12/15'     98       123     275.0
# ...

# %%
import seaborn as sns

# %%
sns.scatterplot(x=df["Pulse"],
                y=df["Calories"],
                hue=df["Duration"],
                s=100
                
                
                
                )

# %%
df.head()
# Out:
#    Duration          Date  Pulse  Maxpulse  Calories
# 0        60  '2020/12/01'    110       130     409.1
# 1        60  '2020/12/02'    117       145     479.0
# 2        60  '2020/12/03'    103       135     340.0
# 3        45  '2020/12/04'    109       175     282.4
# 4        45  '2020/12/05'    117       148     406.0

# %%
sns.barplot(x=df["Pulse"],y=df['Calories'])
